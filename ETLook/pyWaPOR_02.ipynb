# %%
# !pip install pywapor

# %%
# !pip install ipywidgets

# %%
# !pip install scikit-learn

# %% [markdown]
# ### Set Parameters

# %%
import pywapor
import matplotlib.pyplot as plt

# User inputs.
timelim = ["2021-07-01", "2021-07-11"]
latlim = [-33.996944, -33.754444]
lonlim = [18.754444, 18.996944]
project_folder = r"Z:\ETLook\Data_2022-11-10"

# %%
pywapor.collect.accounts.setup("NASA")
# Out:
# C:\Users\zjnie\AppData\Local\r-miniconda\envs\my_pywapor_env\Lib\site-packages\keys.json

# %% [markdown]
# ``` TESTING AREA ~~start```

# %%
sources = "level_1"
bin_length = "DEKAD"
bins = pywapor.general.compositer.time_bins(timelim, bin_length)
sources = pywapor.general.levels.pre_et_look_levels(sources, bin_length = bin_length)
dssZ, sourcesZ = pywapor.collect.downloader.collect_sources(project_folder, sources, latlim, lonlim, [bins[0], bins[-1]], return_fps=False)
# Out:
# <xarray.Dataset>
# Dimensions:                                          (time: 1, y: 384, x: 318)
# Coordinates:
#     spatial_ref                                      uint8 ...
#   * y                                                (y) float64 3.302e+06 .....
#   * x                                                (x) float64 2.94e+06 ......
#   * time                                             (time) datetime64[ns] 20...
#     MODIS_Grid_16DAY_250m_500m_VI_eos_cf_projection  int32 0
# Data variables:
#     ndvi                                             (time, y, x) float32 ...
#     ndvi_qa                                          (time, y, x) float64 ...
# Z:\ETLook\Data_2022-11-09\MODIS\MOD13Q1.061_h20v06.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MOD13Q1.061_h20v06.nc'
# <xarray.Dataset>
# Dimensions:                                          (time: 2, y: 384, x: 318)
# Coordinates:
#     spatial_ref                                      uint8 ...
#   * y                                                (y) float64 3.302e+06 .....
#   * x                                                (x) float64 2.94e+06 ......
#   * time                                             (time) datetime64[ns] 20...
#     MODIS_Grid_16DAY_250m_500m_VI_eos_cf_projection  int32 0
# Data variables:
#     ndvi                                             (time, y, x) float32 ...
#     ndvi_qa                                          (time, y, x) float64 ...
# Z:\ETLook\Data_2022-11-09\MODIS\MYD13Q1.061_h20v06.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MYD13Q1.061_h20v06.nc'
# <xarray.Dataset>
# Dimensions:                          (time: 27, y: 192, x: 159)
# Coordinates:
#     spatial_ref                      uint8 ...
#   * y                                (y) float64 3.302e+06 ... 3.214e+06
#   * x                                (x) float64 2.94e+06 ... 3.013e+06
#   * time                             (time) datetime64[ns] 2021-06-15 ... 202...
#     MOD_Grid_BRDF_eos_cf_projection  int32 0
# Data variables:
#     white_r0                         (time, y, x) float32 ...
#     black_r0                         (time, y, x) float32 ...
#     r0_qa                            (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\MODIS\MCD43A3.061_h20v06.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MCD43A3.061_h20v06.nc'
# <xarray.Dataset>
# Dimensions:                                     (time: 30, y: 96, x: 80)
# Coordinates:
#     spatial_ref                                 uint8 ...
#   * y                                           (y) float64 3.302e+06 ... 3.2...
#   * x                                           (x) float64 2.94e+06 ... 3.01...
#   * time                                        (time) datetime64[ns] 2021-06...
#     MODIS_Grid_Daily_1km_LST_eos_cf_projection  int32 0
# Data variables:
#     lst                                         (time, y, x) float32 ...
#     lst_hour                                    (time, y, x) float32 ...
#     lst_qa                                      (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\MODIS\MOD11A1.061_h20v06.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MOD11A1.061_h20v06.nc'
#         --> Collect attempt 1 of 2 for `se_root.v2` failed, trying again after other sources have been collected. (TypeError: argument of type 'int' is not iterable).
# <xarray.Dataset>
# Dimensions:                                     (time: 30, y: 96, x: 80)
# Coordinates:
#     spatial_ref                                 uint8 ...
#   * y                                           (y) float64 3.302e+06 ... 3.2...
#   * x                                           (x) float64 2.94e+06 ... 3.01...
#   * time                                        (time) datetime64[ns] 2021-06...
#     MODIS_Grid_Daily_1km_LST_eos_cf_projection  int32 0
# Data variables:
#     lst                                         (time, y, x) float32 ...
#     lst_hour                                    (time, y, x) float32 ...
#     lst_qa                                      (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\MODIS\MYD11A1.061_h20v06.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MYD11A1.061_h20v06.nc'
# Z:\ETLook\Data_2022-11-09\CHIRPS\P05_temp.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\CHIRPS\\P05_temp.nc'
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 362, x: 2882)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.0 29.0 29.0 29.0 29.0 ... 28.9 28.9 28.9 28.9
#   * x            (x) float64 30.2 30.2 30.2 30.2 30.2 ... 31.0 31.0 31.0 31.0
#   * time         (time) datetime64[ns] 2000-02-11
# Data variables:
#     z            (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\SRTM\30M_N28E030.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\SRTM\\30M_N28E030.nc'
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 362, x: 722)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.0 29.0 29.0 29.0 29.0 ... 28.9 28.9 28.9 28.9
#   * x            (x) float64 31.0 31.0 31.0 31.0 31.0 ... 31.2 31.2 31.2 31.2
#   * time         (time) datetime64[ns] 2000-02-11
# Data variables:
#     z            (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\SRTM\30M_N28E031.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\SRTM\\30M_N28E031.nc'
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 2522, x: 2882)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.7 29.7 29.7 29.7 29.7 ... 29.0 29.0 29.0 29.0
#   * x            (x) float64 30.2 30.2 30.2 30.2 30.2 ... 31.0 31.0 31.0 31.0
#   * time         (time) datetime64[ns] 2000-02-11
# Data variables:
#     z            (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\SRTM\30M_N29E030.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\SRTM\\30M_N29E030.nc'
# <xarray.Dataset>
# Dimensions:      (time: 1, y: 2522, x: 722)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.7 29.7 29.7 29.7 29.7 ... 29.0 29.0 29.0 29.0
#   * x            (x) float64 31.0 31.0 31.0 31.0 31.0 ... 31.2 31.2 31.2 31.2
#   * time         (time) datetime64[ns] 2000-02-11
# Data variables:
#     z            (time, y, x) float32 ...
# Z:\ETLook\Data_2022-11-09\SRTM\30M_N29E031.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\SRTM\\30M_N29E031.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210614.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210614.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210615.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210615.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210616.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210616.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210617.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210617.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210618.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210618.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210619.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210619.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210620.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210620.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210621.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210621.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210622.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210622.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210623.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210623.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210624.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210624.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210625.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210625.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210626.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210626.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210627.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210627.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210628.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210628.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210629.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210629.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210630.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210630.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210701.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210701.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210702.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210702.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210703.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210703.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210704.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210704.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210705.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210705.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210706.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210706.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210707.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210707.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210708.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210708.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210709.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210709.nc'
# Z:\ETLook\Data_2022-11-09\MERRA2\M2T1NXRAD.5.12.4_20210710.nc  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MERRA2\\M2T1NXRAD.5.12.4_20210710.nc'
# <xarray.Dataset>
# Dimensions:      (time: 213, y: 5, x: 5)
# Coordinates:
#   * time         (time) datetime64[ns] 2021-06-14T13:30:00 ... 2021-07-11T01:...
#   * y            (y) float64 29.75 29.5 29.25 29.0 28.75
#   * x            (x) float64 30.0 30.31 30.62 30.94 31.25
#     spatial_ref  int32 ...
# Data variables:
#     t_air        (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     u2m          (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     v2m          (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     qv           (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     p_air        (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     p_air_0      (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     wv           (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     t_air_max    (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
#     t_air_min    (time, y, x) float32 dask.array<chunksize=(213, 5, 5), meta=np.ndarray>
# Z:\ETLook\Data_2022-11-09\GEOS5\inst3_2d_asm_Nx_temp.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\GEOS5\\inst3_2d_asm_Nx_temp.nc'
# 100%|██████████|
# <xarray.Dataset>
# Dimensions:      (y: 288, x: 360)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.7 29.7 29.69 29.69 ... 28.91 28.91 28.91 28.9
#   * x            (x) float64 30.2 30.2 30.21 30.21 ... 31.19 31.19 31.19 31.2
# Data variables:
#     lulc         (y, x) float32 dask.array<chunksize=(288, 360), meta=np.ndarray>
#     land_mask    (y, x) float32 dask.array<chunksize=(288, 360), meta=np.ndarray>
#     rs_min       (y, x) float32 dask.array<chunksize=(288, 360), meta=np.ndarray>
#     z_obst_max   (y, x) float32 dask.array<chunksize=(288, 360), meta=np.ndarray>
# Z:\ETLook\Data_2022-11-09\GLOBCOVER\2009_V2.3_Global_temp.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\GLOBCOVER\\2009_V2.3_Global_temp.nc'
#         --> Collect attempt 2 of 2 for `se_root.v2` failed, giving up now, see full traceback below for more info. (TypeError: argument of type 'int' is not iterable).
#
# Traceback (most recent call last):
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\collect\downloader.py", line 70, in collect_sources
#     x = dler(**args)
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\collect\product\MODIS.py", line 343, in download
#     os.rename(fn, fn.replace(".nc", "_to_be_appended.nc"))
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MOD13Q1.061.nc' -> 'Z:\\ETLook\\Data_2022-11-09\\MODIS\\MOD13Q1.061_to_be_appended.nc'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\collect\downloader.py", line 70, in collect_sources
#     x = dler(**args)
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\se_root.py", line 53, in se_root
#     ds_in = pre_se_root.main(folder, latlim, lonlim, timelim, sources, bin_length)
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\pre_se_root.py", line 117, in main
#     other_dss, other_sources = downloader.collect_sources(folder, other_sources, latlim, lonlim, buffered_timelim, return_fps = False)
#   File "c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\pywapor\collect\downloader.py", line 74, in collect_sources
#     if "NetCDF: Filter error: unimplemented filter encountered" in e.args[0]:
# TypeError: argument of type 'int' is not iterable
# --> Continuing run without `se_root` from `v2`.
# --> Continuing run without `se_root`, couldn't collect any product.
# <xarray.Dataset>
# Dimensions:      (y: 403, x: 493)
# Coordinates:
#     spatial_ref  |S1 ...
#   * y            (y) float64 29.75 29.75 29.74 29.74 ... 28.86 28.86 28.85 28.85
#   * x            (x) float64 30.15 30.15 30.16 30.16 ... 31.24 31.24 31.25 31.25
# Data variables:
#     lw_offset    (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     lw_slope     (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     z_oro        (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     rn_offset    (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     rn_slope     (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     t_amp_year   (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     t_opt        (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
#     vpd_slope    (y, x) float64 dask.array<chunksize=(403, 493), meta=np.ndarray>
# Z:\ETLook\Data_2022-11-09\STATICS\WaPOR2_temp.nc  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-09\\STATICS\\WaPOR2_temp.nc'

# %% [markdown]
# ``` TESTING AREA ~~end ```

# %% [markdown]
# ### Download Data

# %%
# Download and prepare input data.
ds_in  = pywapor.pre_et_look.main(project_folder, latlim, lonlim, timelim)
# Out:
# > PRE_ET_LOOK
#     --> Collecting `ndvi` from `MODIS.MOD13Q1.061`.
#         --> Applying 'mask_qa' to `ndvi`.
#         --> Saving merged data.
#             > peak-memory-usage: 263.6KB, execution-time: 0:00:02.976349.
#             > chunksize|dimsize: []
#             > timesize: 1 [2021-07-04T00:00, ..., 2021-07-04T00:00]
#     --> Collecting `ndvi` from `MODIS.MYD13Q1.061`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MODIS\\MOD13Q1.061_h19v12.nc'
#         --> Applying 'mask_qa' to `ndvi`.
#         --> Saving merged data.
#             > peak-memory-usage: 300.5KB, execution-time: 0:00:02.104095.
#             > chunksize|dimsize: []
#             > timesize: 2 [2021-06-26T00:00, ..., 2021-07-12T00:00]
#     --> Collecting `r0` from `MODIS.MCD43A3.061`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MODIS\\MYD13Q1.061_h19v12.nc'
#         --> Applying 'shortwave_r0' to `r0`.
#         --> Applying 'mask_qa' to `r0`.
#         --> Saving merged data.
#             > peak-memory-usage: 835.3KB, execution-time: 0:00:02.132419.
#             > chunksize|dimsize: []
#             > timesize: 27 [2021-06-15T12:00, ..., 2021-07-11T12:00]
#     --> Collecting `se_root` from `se_root.v2`.
#         > PRE_SE_ROOT
#             --> Collecting `lst` from `MODIS.MOD11A1.061`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MODIS\\MCD43A3.061_h19v12.nc'
#                 --> Applying 'mask_bitwise_qa' to `lst`.
#                 --> Applying 'expand_time_dim' to `lst`.
#                 --> Saving merged data.
#                     > peak-memory-usage: 351.1KB, execution-time: 0:00:02.123663.
#                     > chunksize|dimsize: []
#                     > timesize: 13 [2021-06-12T10:24, ..., 2021-07-11T09:54]
#             --> Collecting `lst` from `MODIS.MYD11A1.061`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MODIS\\MOD11A1.061_h19v12.nc'
#                 --> Applying 'mask_bitwise_qa' to `lst`.
#                 --> Applying 'expand_time_dim' to `lst`.
#                 --> Saving merged data.
#                     > peak-memory-usage: 704.8KB, execution-time: 0:00:02.135744.
#                     > chunksize|dimsize: []
#                     > timesize: 14 [2021-06-13T13:48, ..., 2021-07-11T14:11]
#             --> Collecting `ndvi` from `MODIS.MOD13Q1.061`.
#                     > timesize: 1 [2021-07-04T00:00, ..., 2021-07-04T00:00]
#             --> Collecting `ndvi` from `MODIS.MYD13Q1.061`.
#                     > timesize: 2 [2021-06-26T00:00, ..., 2021-07-12T00:00]
#             --> Collecting `t_air`, `t_air_max`, `t_air_min`, `u2m`, `v2m`, `qv`, `wv`, `p_air`, `p_air_0` from `GEOS5.inst3_2d_asm_Nx`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MODIS\\MYD11A1.061_h19v12.nc'
#                 --> Downloading data.
#                     > peak-memory-usage: 1.6MB, execution-time: 0:01:38.757704.
#                     > chunksize|dimsize: []
#                 --> Applying 'kelvin_to_celsius' to `t_air`.
#                 --> Applying 'kelvin_to_celsius' to `t_air_max`.
#                 --> Applying 'kelvin_to_celsius' to `t_air_min`.
#                 --> Applying 'pa_to_kpa' to `p_air`.
#                 --> Applying 'pa_to_kpa' to `p_air_0`.
#                 --> Saving netCDF.
#                     > peak-memory-usage: 2.7MB, execution-time: 0:00:02.449654.
#                     > chunksize|dimsize: []
#                     > timesize: 289 [2021-06-08T13:30, ..., 2021-07-14T13:30]
#             --> Collecting `r0_bare`, `r0_full` from `STATICS.WaPOR2`.
#                 --> Saving WaPOR2.nc.
#                     > peak-memory-usage: 1.9MB, execution-time: 0:00:02.133865.
#                     > chunksize|dimsize: []
#             --> Using `MYD11A1.061.nc` as reprojecting example.
#                 > shape: (24, 34), res: 0.0103° x 0.0103°.
#             --> Using `MYD13Q1.061.nc` as reprojecting example.
#                 > shape: (94, 136), res: 0.0026° x 0.0026°.
#             --> Aligning times in `ndvi` (3) with `lst` (27, linear).
#                 > peak-memory-usage: 11.1MB, execution-time: 0:00:02.143874.
#                 > chunksize|dimsize: []
#             --> Aligning times in `p_air` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 565.1KB, execution-time: 0:00:02.126437.
#                 > chunksize|dimsize: []
#             --> Aligning times in `p_air_0` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 602.6KB, execution-time: 0:00:02.189515.
#                 > chunksize|dimsize: []
#             --> Aligning times in `qv` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 600.6KB, execution-time: 0:00:02.135326.
#                 > chunksize|dimsize: []
#             --> Aligning times in `t_air` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 567.7KB, execution-time: 0:00:02.115812.
#                 > chunksize|dimsize: []
#             --> Aligning times in `t_air_max` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 571.2KB, execution-time: 0:00:02.151376.
#                 > chunksize|dimsize: []
#             --> Aligning times in `t_air_min` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 600.8KB, execution-time: 0:00:02.140909.
#                 > chunksize|dimsize: []
#             --> Aligning times in `u2m` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 607.0KB, execution-time: 0:00:02.106691.
#                 > chunksize|dimsize: []
#             --> Aligning times in `v2m` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 604.4KB, execution-time: 0:00:02.137169.
#                 > chunksize|dimsize: []
#             --> Aligning times in `wv` (289) with `lst` (27, linear).
#                 > peak-memory-usage: 604.1KB, execution-time: 0:00:02.128071.
#                 > chunksize|dimsize: []
#             --> Using `MOD13Q1.061.nc` as reprojecting example.
#                 > shape: (94, 136), res: 0.0026° x 0.0026°.
#             --> Selected `reproject_bulk` for reprojection of MOD11A1.061.nc.
#                 --> Applying `reproject_bulk` to MOD11A1.061.nc:lst (nearest).
#                     > peak-memory-usage: 5.3MB, execution-time: 0:00:02.154768.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of p_air_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.3KB, execution-time: 0:00:00.060982.
#                 --> Saving reprojected data from p_air_i.nc:p_air (bilinear).
#                     > peak-memory-usage: 5.9MB, execution-time: 0:00:02.170303.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of p_air_0_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.5KB, execution-time: 0:00:00.057977.
#                 --> Saving reprojected data from p_air_0_i.nc:p_air_0 (bilinear).
#                     > peak-memory-usage: 5.9MB, execution-time: 0:00:02.152450.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of qv_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.6KB, execution-time: 0:00:00.064961.
#                 --> Saving reprojected data from qv_i.nc:qv (bilinear).
#                     > peak-memory-usage: 5.9MB, execution-time: 0:00:02.151885.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of WaPOR2.nc.
#                 --> Correcting src_ds.
#                     > peak-memory-usage: 369.2KB, execution-time: 0:00:02.125966.
#                     > chunksize|dimsize: []
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018994.
#                 --> Saving reprojected data from WaPOR2_fixed.nc:r0_bare (bilinear).
#                     > peak-memory-usage: 204.6KB, execution-time: 0:00:02.130220.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of WaPOR2.nc.
#                 --> Correcting src_ds.
#                     > peak-memory-usage: 370.3KB, execution-time: 0:00:02.118865.
#                     > chunksize|dimsize: []
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018980.
#                 --> Saving reprojected data from WaPOR2_fixed.nc:r0_full (bilinear).
#                     > peak-memory-usage: 204.5KB, execution-time: 0:00:02.133820.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of t_air_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.5KB, execution-time: 0:00:00.054983.
#                 --> Saving reprojected data from t_air_i.nc:t_air (bilinear).
#                     > peak-memory-usage: 5.9MB, execution-time: 0:00:02.168079.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of t_air_max_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.5KB, execution-time: 0:00:00.053983.
#                 --> Saving reprojected data from t_air_max_i.nc:t_air_max (bilinear).
#                     > peak-memory-usage: 5.9MB, execution-time: 0:00:02.151433.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of t_air_min_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.5KB, execution-time: 0:00:00.059979.
#                 --> Saving reprojected data from t_air_min_i.nc:t_air_min (bilinear).
#                     > peak-memory-usage: 5.3MB, execution-time: 0:00:02.151911.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of u2m_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.4KB, execution-time: 0:00:00.060979.
#                 --> Saving reprojected data from u2m_i.nc:u2m (bilinear).
#                     > peak-memory-usage: 5.3MB, execution-time: 0:00:02.159803.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of v2m_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.4KB, execution-time: 0:00:00.057489.
#                 --> Saving reprojected data from v2m_i.nc:v2m (bilinear).
#                     > peak-memory-usage: 5.3MB, execution-time: 0:00:02.173291.
#                     > chunksize|dimsize: []
#             --> Selected `reproject_chunk` for reprojection of wv_i.nc.
#                 --> Warping VRT to netCDF.
#                     > peak-memory-usage: 5.5KB, execution-time: 0:00:00.052982.
#                 --> Saving reprojected data from wv_i.nc:wv (bilinear).
#                     > peak-memory-usage: 5.3MB, execution-time: 0:00:02.136750.
#                     > chunksize|dimsize: []
#             --> Applying 'rename_meteo'.
#             --> Applying 'add_constants'.
#             --> Applying 'bt_to_lst'.
#             --> Applying 'drop_empty_times'.
#             --> Creating merged file `se_root_in.nc`.
#                 > peak-memory-usage: 3.2MB, execution-time: 0:00:03.141336.
#                 > chunksize|dimsize: []
#         < PRE_SE_ROOT (0:03:35.946571)
#         > SE_ROOT
#             --> Running `se_root` (v2).
#             --> Calculating `seasonal_correction`.
#             --> Calculating `declination`.
#             --> Calculating `day_angle`.
#             --> Calculating `air_pressure_kpa2mbar`.
#             --> Calculating `air_pressure_kpa2mbar`.
#             --> Calculating `vegetation_cover`.
#             --> Calculating `air_temperature_kelvin_inst`.
#             --> Calculating `air_temperature_kelvin`.
#             --> Calculating `vapour_pressure_from_specific_humidity_inst`.
#             --> Calculating `vapour_pressure_from_specific_humidity`.
#             --> Calculating `specific_humidity_from_vapour_pressure`.
#             --> Calculating `moist_air_density_inst`.
#             --> Calculating `moist_air_density`.
#             --> Calculating `dry_air_density_inst`.
#             --> Calculating `dry_air_density`.
#             --> Calculating `air_density_inst`.
#             --> Calculating `air_density`.
#             --> Calculating `wind_speed_blending_height_bare`.
#             --> Calculating `longitude_rad`.
#             --> Calculating `latitude_rad`.
#             --> Calculating `hour_angle`.
#             --> Calculating `inverse_earth_sun_distance`.
#             --> Calculating `solar_elevation_angle`.
#             --> Calculating `solar_elevation_angle_refracted`.
#             --> Calculating `relative_optical_airmass`.
#             --> Calculating `rayleigh_optical_thickness`.
#             --> Calculating `linke_turbidity`.
#             --> Calculating `extraterrestrial_irradiance_normal`.
#             --> Calculating `beam_irradiance_normal_clear`.
#             --> Calculating `beam_irradiance_horizontal_clear`.
#             --> Calculating `diffuse_irradiance_horizontal_clear`.
#             --> Calculating `ra_clear_horizontal`.
#             --> Calculating `atmospheric_emissivity_inst`.
#             --> Calculating `net_radiation_bare`.
#             --> Calculating `net_radiation_full`.
#             --> Calculating `sensible_heat_flux_bare`.
#             --> Calculating `sensible_heat_flux_full`.
#             --> Calculating `wind_speed_blending_height_full_inst`.
#             --> Calculating `friction_velocity_bare_inst`.
#             --> Calculating `friction_velocity_full_inst`.
#             --> Calculating `monin_obukhov_length_bare`.
#             --> Calculating `monin_obukhov_length_full`.
#             --> Calculating `wind_speed_soil_inst`.
#             --> Calculating `psi_m`.
#             --> Calculating `aerodynamical_resistance_forced_convection_soil`.
#             --> Calculating `aerodynamical_resistance_forced_convection_bare`.
#             --> Calculating `psi_m`.
#             --> Calculating `psi_h`.
#             --> Calculating `aerodynamical_resistance_forced_convection_full`.
#             --> Calculating `psi_m`.
#             --> Calculating `psi_m`.
#             --> Calculating `psi_h`.
#             --> Calculating `psi_h`.
#             --> Calculating `maximum_temperature_bare`.
#             --> Calculating `maximum_temperature_full`.
#             --> Calculating `wet_bulb_temperature_inst_new`.
#             --> Calculating `maximum_temperature`.
#             --> Calculating `wet_bulb_temperature_kelvin_inst`.
#             --> Calculating `air_temperature_kelvin`.
#             --> Calculating `minimum_temperature`.
#             --> Calculating `soil_moisture_from_maximum_temperature`.
# c:\Users\zjnie\AppData\Local\R-MINI~1\envs\my_pywapor_env\lib\site-packages\dask\core.py:119: RuntimeWarning: invalid value encountered in power
#   return func(*(_execute_task(a, cache) for a in args))
#             --> Saving output to `se_root_out.nc`.
#                 > peak-memory-usage: 49.9MB, execution-time: 0:00:03.014123.
#                 > chunksize|dimsize: []
#         < SE_ROOT (0:00:07.012815)
#             > timesize: 14 [2021-06-27T09:41, ..., 2021-07-11T14:11]
#     --> Collecting `p` from `CHIRPS.P05`.
#         --> Saving merged data.
#             > peak-memory-usage: 425.8KB, execution-time: 0:00:02.140073.
#             > chunksize|dimsize: []
#             > timesize: 27 [2021-06-15T00:30, ..., 2021-07-11T00:30]
#     --> Collecting `z` from `SRTM.30M`.
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\CHIRPS\\P05_temp.nc'
#         --> Saving merged data.
#             > peak-memory-usage: 6.6MB, execution-time: 0:00:02.244417.
#             > chunksize|dimsize: []
#             > timesize: 1 [2000-02-11T00:00, ..., 2000-02-11T00:00]
#     --> Collecting `ra` from `MERRA2.M2T1NXRAD.5.12.4`.
#  failed to remove:
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\SRTM\\30M_S34E018.nc'
#         --> Saving merged data.
#             > peak-memory-usage: 452.7KB, execution-time: 0:00:02.157416.
#             > chunksize|dimsize: []
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210614.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210615.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210616.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210617.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210618.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210619.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210620.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210621.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210622.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210623.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210624.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210625.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210626.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210627.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210628.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210629.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210630.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210701.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210702.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210703.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210704.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210705.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210706.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210707.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210708.nc'
#             > timesize: 324 [2021-06-14T13:00, ..., 2021-07-11T00:00]
#     --> Collecting `t_air`, `t_air_max`, `t_air_min`, `u2m`, `v2m`, `qv`, `p_air`, `p_air_0`, `wv` from `GEOS5.inst3_2d_asm_Nx`.
#             > timesize: 289 [2021-06-08T13:30, ..., 2021-07-14T13:30]
#     --> Collecting `land_mask`, `rs_min`, `z_obst_max` from `GLOBCOVER.2009_V2.3_Global`.
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210709.nc'
#  str vers. failed
#  [WinError 32] The process cannot access the file because it is being used by another process: 'Z:\\ETLook\\Data_2022-11-10\\MERRA2\\M2T1NXRAD.5.12.4_20210710.nc'
#         --> Applying 'lulc_to_x' to `land_mask`.
#         --> Applying 'lulc_to_x' to `rs_min`.
#         --> Applying 'lulc_to_x' to `z_obst_max`.
#         --> Saving 2009_V2.3_Global.nc.
#             > peak-memory-usage: 1.3MB, execution-time: 0:00:02.200751.
#             > chunksize|dimsize: []
#     --> Collecting `lw_offset`, `lw_slope`, `z_oro`, `rn_offset`, `rn_slope`, `t_amp_year`, `t_opt`, `vpd_slope` from `STATICS.WaPOR2`.
#         --> Saving WaPOR2_appendix.nc.
#             > peak-memory-usage: 1.5MB, execution-time: 0:00:02.328260.
#             > chunksize|dimsize: []
#         --> Appending new variables (`lw_offset`, `lw_slope`, `z_oro`, `rn_offset`, `rn_slope`, `t_amp_year`, `t_opt`, `vpd_slope`) to existing file.
#             > peak-memory-usage: 558.1KB, execution-time: 0:00:02.409845.
#             > chunksize|dimsize: []
#     --> Compositing 26 variables.
#         --> (1/26) Compositing `ndvi` (mean).
#             --> Using `MYD13Q1.061.nc` as reprojecting example.
#                 > shape: (94, 136), res: 0.0026° x 0.0026°.
#             --> Saving `ndvi` composites.
#                 > peak-memory-usage: 793.2KB, execution-time: 0:00:02.083037.
#                 > chunksize|dimsize: []
#         --> (2/26) Compositing `r0` (mean).
#             --> Saving `r0` composites.
#                 > peak-memory-usage: 1.3MB, execution-time: 0:00:02.104284.
#                 > chunksize|dimsize: []
#         --> (3/26) Compositing `se_root` (max).
#             --> Saving `se_root` composites.
#                 > peak-memory-usage: 2.6MB, execution-time: 0:00:02.076913.
#                 > chunksize|dimsize: []
#         --> (4/26) Compositing `p` (mean).
#             --> Saving `p` composites.
#                 > peak-memory-usage: 12.9KB, execution-time: 0:00:02.110916.
#                 > chunksize|dimsize: []
#         --> (5/26) Compositing `z` (None).
#             --> Saving `z` composites.
#                 > peak-memory-usage: 11.7MB, execution-time: 0:00:02.265699.
#                 > chunksize|dimsize: []
#         --> (6/26) Compositing `ra` (mean).
#             --> Saving `ra` composites.
#                 > peak-memory-usage: 25.6KB, execution-time: 0:00:02.091900.
#                 > chunksize|dimsize: []
#         --> (7/26) Compositing `t_air` (mean).
#             --> Saving `t_air` composites.
#                 > peak-memory-usage: 20.1KB, execution-time: 0:00:02.109458.
#                 > chunksize|dimsize: []
#         --> (8/26) Compositing `t_air_max` (max).
#             --> Saving `t_air_max` composites.
#                 > peak-memory-usage: 23.5KB, execution-time: 0:00:02.092619.
#                 > chunksize|dimsize: []
#         --> (9/26) Compositing `t_air_min` (min).
#             --> Saving `t_air_min` composites.
#                 > peak-memory-usage: 18.3KB, execution-time: 0:00:02.166285.
#                 > chunksize|dimsize: []
#         --> (10/26) Compositing `u2m` (mean).
#             --> Saving `u2m` composites.
#                 > peak-memory-usage: 23.6KB, execution-time: 0:00:02.107874.
#                 > chunksize|dimsize: []
#         --> (11/26) Compositing `v2m` (mean).
#             --> Saving `v2m` composites.
#                 > peak-memory-usage: 20.2KB, execution-time: 0:00:02.084438.
#                 > chunksize|dimsize: []
#         --> (12/26) Compositing `qv` (mean).
#             --> Saving `qv` composites.
#                 > peak-memory-usage: 23.3KB, execution-time: 0:00:02.111996.
#                 > chunksize|dimsize: []
#         --> (13/26) Compositing `p_air` (mean).
#             --> Saving `p_air` composites.
#                 > peak-memory-usage: 20.6KB, execution-time: 0:00:02.095947.
#                 > chunksize|dimsize: []
#         --> (14/26) Compositing `p_air_0` (mean).
#             --> Saving `p_air_0` composites.
#                 > peak-memory-usage: 22.6KB, execution-time: 0:00:02.107818.
#                 > chunksize|dimsize: []
#         --> (15/26) Compositing `wv` (mean).
#             --> Saving `wv` composites.
#                 > peak-memory-usage: 21.1KB, execution-time: 0:00:02.106773.
#                 > chunksize|dimsize: []
#         --> (16/26) Compositing `land_mask` (None).
#             --> Saving `land_mask` composites.
#                 > peak-memory-usage: 71.3KB, execution-time: 0:00:02.077589.
#                 > chunksize|dimsize: []
#         --> (17/26) Compositing `rs_min` (None).
#             --> Saving `rs_min` composites.
#                 > peak-memory-usage: 71.2KB, execution-time: 0:00:02.093071.
#                 > chunksize|dimsize: []
#         --> (18/26) Compositing `z_obst_max` (None).
#             --> Saving `z_obst_max` composites.
#                 > peak-memory-usage: 79.6KB, execution-time: 0:00:02.071285.
#                 > chunksize|dimsize: []
#         --> (19/26) Compositing `lw_offset` (None).
#             --> Saving `lw_offset` composites.
#                 > peak-memory-usage: 194.9KB, execution-time: 0:00:02.090014.
#                 > chunksize|dimsize: []
#         --> (20/26) Compositing `lw_slope` (None).
#             --> Saving `lw_slope` composites.
#                 > peak-memory-usage: 194.9KB, execution-time: 0:00:02.086838.
#                 > chunksize|dimsize: []
#         --> (21/26) Compositing `z_oro` (None).
#             --> Saving `z_oro` composites.
#                 > peak-memory-usage: 194.9KB, execution-time: 0:00:02.083432.
#                 > chunksize|dimsize: []
#         --> (22/26) Compositing `rn_offset` (None).
#             --> Saving `rn_offset` composites.
#                 > peak-memory-usage: 195.1KB, execution-time: 0:00:02.075853.
#                 > chunksize|dimsize: []
#         --> (23/26) Compositing `rn_slope` (None).
#             --> Saving `rn_slope` composites.
#                 > peak-memory-usage: 195.1KB, execution-time: 0:00:02.070010.
#                 > chunksize|dimsize: []
#         --> (24/26) Compositing `t_amp_year` (None).
#             --> Saving `t_amp_year` composites.
#                 > peak-memory-usage: 195.0KB, execution-time: 0:00:02.077573.
#                 > chunksize|dimsize: []
#         --> (25/26) Compositing `t_opt` (None).
#             --> Saving `t_opt` composites.
#                 > peak-memory-usage: 203.4KB, execution-time: 0:00:02.082511.
#                 > chunksize|dimsize: []
#         --> (26/26) Compositing `vpd_slope` (None).
#             --> Saving `vpd_slope` composites.
#                 > peak-memory-usage: 194.9KB, execution-time: 0:00:02.075391.
#                 > chunksize|dimsize: []
#     --> Using `MOD13Q1.061.nc` as reprojecting example.
#         > shape: (94, 136), res: 0.0026° x 0.0026°.
#     --> Selected `reproject_chunk` for reprojection of r0_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.4KB, execution-time: 0:00:00.017980.
#         --> Saving reprojected data from r0_bin.nc:r0 (bilinear).
#             > peak-memory-usage: 200.1KB, execution-time: 0:00:02.126452.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of p_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.057982.
#         --> Saving reprojected data from p_bin.nc:p (bilinear).
#             > peak-memory-usage: 199.9KB, execution-time: 0:00:02.125297.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of z_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.046986.
#         --> Saving reprojected data from z_bin.nc:z (bilinear).
#             > peak-memory-usage: 203.7KB, execution-time: 0:00:02.114738.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of ra_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.017993.
#         --> Saving reprojected data from ra_bin.nc:ra (bilinear).
#             > peak-memory-usage: 200.2KB, execution-time: 0:00:02.118169.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of t_air_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.024973.
#         --> Saving reprojected data from t_air_bin.nc:t_air (bilinear).
#             > peak-memory-usage: 198.2KB, execution-time: 0:00:02.107791.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of t_air_max_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.019994.
#         --> Saving reprojected data from t_air_max_bin.nc:t_air_max (bilinear).
#             > peak-memory-usage: 595.1KB, execution-time: 0:00:02.114155.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of t_air_min_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.017998.
#         --> Saving reprojected data from t_air_min_bin.nc:t_air_min (bilinear).
#             > peak-memory-usage: 200.5KB, execution-time: 0:00:02.106141.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of u2m_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.8KB, execution-time: 0:00:00.042987.
#         --> Saving reprojected data from u2m_bin.nc:u2m (bilinear).
#             > peak-memory-usage: 595.5KB, execution-time: 0:00:02.124373.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of v2m_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.026009.
#         --> Saving reprojected data from v2m_bin.nc:v2m (bilinear).
#             > peak-memory-usage: 201.2KB, execution-time: 0:00:02.115853.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of qv_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.017994.
#         --> Saving reprojected data from qv_bin.nc:qv (bilinear).
#             > peak-memory-usage: 595.4KB, execution-time: 0:00:02.129180.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of p_air_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018998.
#         --> Saving reprojected data from p_air_bin.nc:p_air (bilinear).
#             > peak-memory-usage: 200.7KB, execution-time: 0:00:02.096486.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of p_air_0_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.016994.
#         --> Saving reprojected data from p_air_0_bin.nc:p_air_0 (bilinear).
#             > peak-memory-usage: 595.4KB, execution-time: 0:00:02.095331.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of wv_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.021992.
#         --> Saving reprojected data from wv_bin.nc:wv (bilinear).
#             > peak-memory-usage: 200.9KB, execution-time: 0:00:02.111437.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of land_mask_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.029990.
#         --> Saving reprojected data from land_mask_bin.nc:land_mask (nearest).
#             > peak-memory-usage: 203.9KB, execution-time: 0:00:02.100797.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of rs_min_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.016994.
#         --> Saving reprojected data from rs_min_bin.nc:rs_min (nearest).
#             > peak-memory-usage: 597.5KB, execution-time: 0:00:02.097058.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of z_obst_max_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.016982.
#         --> Saving reprojected data from z_obst_max_bin.nc:z_obst_max (nearest).
#             > peak-memory-usage: 204.1KB, execution-time: 0:00:02.118991.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of lw_offset_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.022993.
#         --> Saving reprojected data from lw_offset_bin.nc:lw_offset (bilinear).
#             > peak-memory-usage: 204.0KB, execution-time: 0:00:02.105289.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of lw_slope_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018993.
#         --> Saving reprojected data from lw_slope_bin.nc:lw_slope (bilinear).
#             > peak-memory-usage: 597.8KB, execution-time: 0:00:02.095420.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of z_oro_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.021992.
#         --> Saving reprojected data from z_oro_bin.nc:z_oro (bilinear).
#             > peak-memory-usage: 204.1KB, execution-time: 0:00:02.115221.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of rn_offset_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.017994.
#         --> Saving reprojected data from rn_offset_bin.nc:rn_offset (bilinear).
#             > peak-memory-usage: 204.0KB, execution-time: 0:00:02.097327.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of rn_slope_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018993.
#         --> Saving reprojected data from rn_slope_bin.nc:rn_slope (bilinear).
#             > peak-memory-usage: 597.9KB, execution-time: 0:00:02.107085.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of t_amp_year_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.017994.
#         --> Saving reprojected data from t_amp_year_bin.nc:t_amp_year (bilinear).
#             > peak-memory-usage: 203.9KB, execution-time: 0:00:02.094044.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of t_opt_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.035989.
#         --> Saving reprojected data from t_opt_bin.nc:t_opt (bilinear).
#             > peak-memory-usage: 203.9KB, execution-time: 0:00:02.115360.
#             > chunksize|dimsize: []
#     --> Selected `reproject_chunk` for reprojection of vpd_slope_bin.nc.
#         --> Warping VRT to netCDF.
#             > peak-memory-usage: 4.6KB, execution-time: 0:00:00.018994.
#         --> Saving reprojected data from vpd_slope_bin.nc:vpd_slope (bilinear).
#             > peak-memory-usage: 597.7KB, execution-time: 0:00:02.097293.
#             > chunksize|dimsize: []
#     --> Calculating local means (r = 0.25°) of `z`.
#         --> Filling 3854 missing pixels in 'z'.
#     --> Applying 'lapse_rate'.
#     --> Applying 'rename_vars'.
#     --> Applying 'fill_attrs'.
#     --> Applying 'calc_doys'.
#     --> Applying 'add_constants'.
#     --> Creating merged file `et_look_in.nc`.
#         > peak-memory-usage: 485.6KB, execution-time: 0:00:03.336486.
#         > chunksize|dimsize: []
# < PRE_ET_LOOK (0:11:16.220284)

# %% [markdown]
# ### Run Model

# %%
# Run the model.
ds_out = pywapor.et_look.main(ds_in)
# Out:
# > ET_LOOK
#     --> Running `et_look` (v2).
#     --> Calculating `declination`.
#     --> Calculating `inverse_earth_sun_distance`.
#     --> Calculating `vegetation_cover`.
#     --> Calculating `leaf_area_index`.
#     --> Calculating `effective_leaf_area_index`.
#     --> Calculating `soil_fraction`.
#     --> Calculating `latitude_rad`.
#     --> Calculating `sunset_hour_angle`.
#     --> Calculating `daily_solar_radiation_toa_flat`.
#     --> Calculating `transmissivity`.
#     --> Calculating `stress_radiation`.
#     --> Calculating `air_pressure_kpa2mbar`.
#     --> Calculating `air_pressure_daily`.
#     --> Calculating `air_pressure`.
#     --> Calculating `vapour_pressure_from_specific_humidity_daily`.
#     --> Calculating `vapour_pressure_from_specific_humidity`.
#     --> Calculating `saturated_vapour_pressure`.
#     --> Calculating `vapour_pressure_deficit_daily`.
#     --> Calculating `vapour_pressure_deficit`.
#     --> Calculating `stress_vpd`.
#     --> Calculating `stress_temperature`.
#     --> Calculating `atmospheric_canopy_resistance`.
#     --> Calculating `air_temperature_kelvin_daily`.
#     --> Calculating `air_temperature_kelvin`.
#     --> Calculating `longwave_radiation_fao`.
#     --> Calculating `interception_mm`.
#     --> Calculating `latent_heat_daily`.
#     --> Calculating `latent_heat`.
#     --> Calculating `interception_wm2`.
#     --> Calculating `net_radiation`.
#     --> Calculating `net_radiation_canopy`.
#     --> Calculating `stress_moisture`.
#     --> Calculating `canopy_resistance`.
#     --> Calculating `obstacle_height`.
#     --> Calculating `roughness_length`.
#     --> Calculating `wind_speed`.
#     --> Calculating `initial_canopy_aerodynamic_resistance`.
#     --> Calculating `wind_speed_blending_height_daily`.
#     --> Calculating `wind_speed_blending_height`.
#     --> Calculating `dry_air_density_daily`.
#     --> Calculating `dry_air_density`.
#     --> Calculating `moist_air_density_daily`.
#     --> Calculating `moist_air_density`.
#     --> Calculating `air_density_daily`.
#     --> Calculating `air_density`.
#     --> Calculating `psychrometric_constant_daily`.
#     --> Calculating `psychrometric_constant`.
#     --> Calculating `slope_saturated_vapour_pressure_daily`.
#     --> Calculating `slope_saturated_vapour_pressure`.
#     --> Calculating `saturated_vapour_pressure`.
#     --> Calculating `initial_daily_transpiration`.
#     --> Calculating `initial_sensible_heat_flux_canopy_daily`.
#     --> Calculating `displacement_height`.
#     --> Calculating `initial_friction_velocity_daily`.
#     --> Calculating `transpiration`.
#     --> Calculating `transpiration_mm`.
#     --> Calculating `net_radiation_soil`.
#     --> Calculating `soil_resistance`.
#     --> Calculating `initial_soil_aerodynamic_resistance`.
#     --> Calculating `initial_friction_velocity_soil_daily`.
#     --> Calculating `soil_thermal_conductivity`.
#     --> Calculating `volumetric_heat_capacity`.
#     --> Calculating `damping_depth`.
#     --> Calculating `bare_soil_heat_flux`.
#     --> Calculating `soil_heat_flux`.
#     --> Calculating `initial_daily_evaporation`.
#     --> Calculating `initial_sensible_heat_flux_soil_daily`.
#     --> Calculating `evaporation`.
#     --> Calculating `evaporation_mm`.
#     --> Calculating `et_actual_mm`.
#     --> Calculating `net_radiation_grass`.
#     --> Calculating `et_reference`.
#     --> Calculating `et_reference_mm`.
#     --> Calculating `air_temperature_kelvin_daily`.
#     --> Calculating `air_temperature_kelvin`.
#     --> Calculating `air_temperature_kelvin_daily`.
#     --> Calculating `air_temperature_kelvin`.
#     --> Calculating `mean_temperature_kelvin_daytime`.
#     --> Calculating `temperature_dependency`.
#     --> Calculating `affinity_constant_co2`.
#     --> Calculating `inhibition_constant_o2`.
#     --> Calculating `co2_o2_specificity_ratio`.
#     --> Calculating `co2_level_annual`.
#     --> Calculating `autotrophic_respiration`.
#     --> Calculating `par`.
#     --> Calculating `fpar`.
#     --> Calculating `co2_fertilisation`.
#     --> Calculating `net_primary_production_max`.
#     --> Calculating `net_primary_production`.
#     --> Saving output to `et_look_out.nc`.
#         > peak-memory-usage: 29.8MB, execution-time: 0:00:04.094269.
#         > chunksize|dimsize: []
# < ET_LOOK (0:00:13.345934)

# %%
ds_out
# Out:
# <xarray.Dataset>
# Dimensions:       (time_bins: 1, y: 94, x: 136)
# Coordinates:
#   * x             (x) float64 18.7 18.71 18.71 18.71 ... 19.04 19.04 19.05 19.05
#   * y             (y) float64 -33.76 -33.76 -33.76 ... -33.99 -33.99 -34.0
#     spatial_ref   int32 0
#   * time_bins     (time_bins) datetime64[ns] 2021-07-01
# Data variables:
#     int_mm        (time_bins, y, x) float64 nan nan nan nan ... nan nan nan nan
#     t_24_mm       (time_bins, y, x) float64 nan nan nan nan ... nan nan nan nan
#     e_24_mm       (time_bins, y, x) float64 nan nan nan nan ... nan nan nan nan
#     et_24_mm      (time_bins, y, x) float64 nan nan nan nan ... nan nan nan nan
#     et_ref_24_mm  (time_bins, y, x) float64 nan 1.038 1.039 ... 0.867 nan nan
#     se_root       (time_bins, y, x) float64 nan 1.0 0.8517 ... 0.9298 nan nan
#     npp           (time_bins, y, x) float64 nan 0.9477 0.8384 ... 0.3058 nan nan

# %%
plt.imshow(ds_out.et_24_mm.isel(time_bins = 0))
